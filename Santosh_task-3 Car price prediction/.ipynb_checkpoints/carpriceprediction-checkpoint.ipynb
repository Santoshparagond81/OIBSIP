# %% [markdown]
# Modules imported

# %%
import pandas as pd

# %%
import numpy as np

# %%
import matplotlib.pyplot as plt

# %%
import seaborn as sns

# %%
from sklearn.model_selection import train_test_split

# %%
from sklearn.linear_model import LinearRegression

# %%
from sklearn.ensemble import RandomForestRegressor

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score

# %%
df=pd.read_csv("car_data.csv")

# %%
df
# Out:
#     Car_Name  Year  Selling_Price  Present_Price  Kms_Driven Fuel_Type  \
# 0       ritz  2014           3.35           5.59       27000    Petrol
# 1        sx4  2013           4.75           9.54       43000    Diesel
# 2       ciaz  2017           7.25           9.85        6900    Petrol
# 3    wagon r  2011           2.85           4.15        5200    Petrol
# 4      swift  2014           4.60           6.87       42450    Diesel
# ..       ...   ...            ...            ...         ...       ...
# 296     city  2016           9.50          11.60       33988    Diesel
# 297     brio  2015           4.00           5.90       60000    Petrol
# 298     city  2009           3.35          11.00       87934    Petrol
# 299     city  2017          11.50          12.50        9000    Diesel
# 300     brio  2016           5.30           5.90        5464    Petrol
#
#     Seller_Type Transmission  Owner
# 0        Dealer       Manual      0
# 1        Dealer       Manual      0
# ...

# %%
df[df["Car_Name"] == "ritz"]
# Out:
#    Car_Name  Year  Selling_Price  Present_Price  Kms_Driven Fuel_Type  \
# 0      ritz  2014           3.35           5.59       27000    Petrol
# 30     ritz  2012           3.10           5.98       51439    Diesel
# 31     ritz  2011           2.35           4.89       54200    Petrol
# 46     ritz  2013           2.65           4.89       64532    Petrol
#
#    Seller_Type Transmission  Owner
# 0       Dealer       Manual      0
# 30      Dealer       Manual      0
# 31      Dealer       Manual      0
# 46      Dealer       Manual      0

# %%
df[df["Car_Name"]=="brio"]
# Out:
#     Car_Name  Year  Selling_Price  Present_Price  Kms_Driven Fuel_Type  \
# 252     brio  2015           5.40           6.82       31427    Petrol
# 255     brio  2012           3.00           5.35       53675    Petrol
# 261     brio  2016           5.50           5.97        5600    Petrol
# 268     brio  2017           4.80           5.80       19000    Petrol
# 274     brio  2014           5.30           6.80       16500    Petrol
# 280     brio  2015           5.25           5.90       14465    Petrol
# 284     brio  2013           3.50           5.90        9800    Petrol
# 291     brio  2015           5.40           6.10       31427    Petrol
# 297     brio  2015           4.00           5.90       60000    Petrol
# 300     brio  2016           5.30           5.90        5464    Petrol
#
#     Seller_Type Transmission  Owner
# 252      Dealer    Automatic      0
# 255      Dealer       Manual      0
# 261      Dealer       Manual      0
# 268      Dealer       Manual      0
# ...

# %%
df["Car_Age"] = 2026 - df["Year"]

# %%
df.shape
# Out:
# (301, 10)

# %%
df.dtypes
# Out:
# Car_Name             str
# Year               int64
# Selling_Price    float64
# Present_Price    float64
# Kms_Driven         int64
# Fuel_Type            str
# Seller_Type          str
# Transmission         str
# Owner              int64
# Car_Age            int64
# dtype: object

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 301 entries, 0 to 300
# Data columns (total 10 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Car_Name       301 non-null    str
#  1   Year           301 non-null    int64
#  2   Selling_Price  301 non-null    float64
#  3   Present_Price  301 non-null    float64
#  4   Kms_Driven     301 non-null    int64
#  5   Fuel_Type      301 non-null    str
#  6   Seller_Type    301 non-null    str
#  7   Transmission   301 non-null    str
#  8   Owner          301 non-null    int64
#  9   Car_Age        301 non-null    int64
# dtypes: float64(2), int64(4), str(4)
# memory usage: 32.4 KB

# %%
df.isnull().sum()
# Out:
# Car_Name         0
# Year             0
# Selling_Price    0
# Present_Price    0
# Kms_Driven       0
# Fuel_Type        0
# Seller_Type      0
# Transmission     0
# Owner            0
# Car_Age          0
# dtype: int64

# %% [markdown]
# checking distribution of categorical values

# %%
print(df.Fuel_Type.value_counts())
print(df.Seller_Type.value_counts())
print(df.Transmission.value_counts())
# Out:
# Fuel_Type
# Petrol    239
# Diesel     60
# CNG         2
# Name: count, dtype: int64
# Seller_Type
# Dealer        195
# Individual    106
# Name: count, dtype: int64
# Transmission
# Manual       261
# Automatic     40
# Name: count, dtype: int64

# %% [markdown]
# Encoding categorical values

# %%
#encoding fuel type column
df.replace({"Fuel_Type":{'Petrol':0,'Diesel':1,'CNG':2}},inplace=True)
#encoding Seller Type column
df.replace({"Seller_Type":{'Dealer':0,'Individual':1}},inplace=True)
#encoding Transmission Column column
df.replace({"Transmission":{'Manual':0,'Automatic':1}},inplace=True)
# Out:
#     Car_Name  Year  Selling_Price  Present_Price  Kms_Driven Fuel_Type  \
# 0       ritz  2014           3.35           5.59       27000         0
# 1        sx4  2013           4.75           9.54       43000         1
# 2       ciaz  2017           7.25           9.85        6900         0
# 3    wagon r  2011           2.85           4.15        5200         0
# 4      swift  2014           4.60           6.87       42450         1
# ..       ...   ...            ...            ...         ...       ...
# 296     city  2016           9.50          11.60       33988         1
# 297     brio  2015           4.00           5.90       60000         0
# 298     city  2009           3.35          11.00       87934         0
# 299     city  2017          11.50          12.50        9000         1
# 300     brio  2016           5.30           5.90        5464         0
#
#     Seller_Type Transmission  Owner  Car_Age
# 0             0            0      0       12
# ...

# %%
df.head()
# Out:
#   Car_Name  Year  Selling_Price  Present_Price  Kms_Driven Fuel_Type  \
# 0     ritz  2014           3.35           5.59       27000         0
# 1      sx4  2013           4.75           9.54       43000         1
# 2     ciaz  2017           7.25           9.85        6900         0
# 3  wagon r  2011           2.85           4.15        5200         0
# 4    swift  2014           4.60           6.87       42450         1
#
#   Seller_Type Transmission  Owner  Car_Age
# 0           0            0      0       12
# 1           0            0      0       13
# 2           0            0      0        9
# 3           0            0      0       15
# 4           0            0      0       12

# %% [markdown]
# Splitting the dataset into training set and testing set

# %%
X=df.drop(["Car_Name","Selling_Price"],axis=1)

# %%
Y=df["Selling_Price"]

# %%
X
# Out:
#      Year  Present_Price  Kms_Driven Fuel_Type Seller_Type Transmission  \
# 0    2014           5.59       27000         0           0            0
# 1    2013           9.54       43000         1           0            0
# 2    2017           9.85        6900         0           0            0
# 3    2011           4.15        5200         0           0            0
# 4    2014           6.87       42450         1           0            0
# ..    ...            ...         ...       ...         ...          ...
# 296  2016          11.60       33988         1           0            0
# 297  2015           5.90       60000         0           0            0
# 298  2009          11.00       87934         0           0            0
# 299  2017          12.50        9000         1           0            0
# 300  2016           5.90        5464         0           0            0
#
#      Owner  Car_Age
# 0        0       12
# 1        0       13
# 2        0        9
# ...

# %%
Y
# Out:
# 0       3.35
# 1       4.75
# 2       7.25
# 3       2.85
# 4       4.60
#        ...
# 296     9.50
# 297     4.00
# 298     3.35
# 299    11.50
# 300     5.30
# Name: Selling_Price, Length: 301, dtype: float64

# %% [markdown]
# splitting training and testing data

# %%
X_train,X_test,Y_train,Y_test=train_test_split(X,Y,test_size=0.1,random_state=2)

# %%
X_train.shape
# Out:
# (270, 8)

# %%
X_test.shape
# Out:
# (31, 8)

# %% [markdown]
# Model training

# %% [markdown]
# 1.Linear Regression

# %%
#loading linear regression model
model=LinearRegression()

# %%
model.fit(X_train,Y_train)
# Out:
# LinearRegression()

# %% [markdown]
# Model evaluation

# %%
#prediction on training data
prediction=model.predict(X_train)

# %%
# R squared error
error_score_lr=metrics.r2_score(Y_train,prediction)
print("r2 score",error_score)
mae_lr = mean_absolute_error(Y_train, prediction)
print("MAE:", mae)
rmse_lr = np.sqrt(mean_squared_error(Y_train, prediction))
print("RMSE:", rmse)
# Out:
# r2 score 0.988982919072927
# MAE: 0.24245481481481493
# RMSE: 0.5468745060188244

# %% [markdown]
# visualize actual prices and predicted prices

# %%
plt.scatter(Y_train,prediction)
plt.xlabel("Actual price")
plt.ylabel("Predicted price")
plt.title("Actual price vs Predicted price")
# Out:
# Text(0.5, 1.0, 'Actual price vs Predicted price')

# %% [markdown]
# Prediction on testing data

# %%
#prediction on testing data
t_prediction=model.predict(X_test)

# %%
# R squared error
error_score_lrtest=metrics.r2_score(Y_test,t_prediction)
print("r2 score",error_score)
mae_lrtest = mean_absolute_error(Y_test,t_prediction)
print("MAE:", mae)
rmse_lrtest = np.sqrt(mean_squared_error(Y_test,t_prediction))
print("RMSE:", rmse)
# Out:
# r2 score 0.988982919072927
# MAE: 0.24245481481481493
# RMSE: 0.5468745060188244

# %%
plt.scatter(Y_test,t_prediction)
plt.xlabel("Actual price")
plt.ylabel("Predicted price")
plt.title("Actual price vs Predicted price")
# Out:
# Text(0.5, 1.0, 'Actual price vs Predicted price')

# %% [markdown]
# 2.Random Forest Regressor

# %%
model=RandomForestRegressor()
model.fit(X_train,Y_train)
# Out:
# RandomForestRegressor()

# %%
#prediction on training data
prediction=model.predict(X_train)

# %%
# R squared error
error_score_rfr=metrics.r2_score(Y_train,prediction)
print("r2 score",error_score)
mae_rfr = mean_absolute_error(Y_train, prediction)
print("MAE:", mae)
rmse_rfr = np.sqrt(mean_squared_error(Y_train, prediction))
print("RMSE:", rmse)
# Out:
# r2 score 0.988982919072927
# MAE: 0.24245481481481493
# RMSE: 0.5468745060188244

# %%
plt.scatter(Y_train,prediction)
plt.xlabel("Actual price")
plt.ylabel("Predicted price")
plt.title("Actual price vs Predicted price")
# Out:
# Text(0.5, 1.0, 'Actual price vs Predicted price')

# %%
#prediction on testing data
t_prediction=model.predict(X_test)

# %%
# R squared error
error_score_rfrtest=metrics.r2_score(Y_test,t_prediction)
print("r2 score",error_score)
mae_rfrtestt = mean_absolute_error(Y_test,t_prediction)
print("MAE:", mae)
rmse_rfrtest = np.sqrt(mean_squared_error(Y_test,t_prediction))
print("RMSE:", rmse)
# Out:
# r2 score 0.988982919072927
# MAE: 0.24245481481481493
# RMSE: 0.5468745060188244

# %%
plt.scatter(Y_test,t_prediction)
plt.xlabel("Actual price")
plt.ylabel("Predicted price")
plt.title("Actual price vs Predicted price")
# Out:
# Text(0.5, 1.0, 'Actual price vs Predicted price')

# %%
plt.scatter(Y_test,t_prediction)
plt.xlabel("Actual price")
plt.ylabel("Predicted price")
plt.title("Actual price vs Predicted price")
# Out:
# Text(0.5, 1.0, 'Actual price vs Predicted price')

# %%
comparison = pd.DataFrame({
    "Model": ["Linear Regression", "Random Forest Regressor"],
    
    "Training MAE": [mae_lr, mae_rfr],
    "Testing MAE": [mae_lrtest, mae_rfrtestt],
    
    "Training RMSE": [rmse_lr, rmse_rfr],
    "Testing RMSE": [rmse_lrtest, rmse_rfrtest],
    
    "Training R2 Score": [error_score_lr, error_score_rfr],
    "Testing R2 Score": [error_score_lrtest, error_score_rfrtest]
})

# %%
comparison
# Out:
#                      Model  Training MAE  Testing MAE  Training RMSE  \
# 0        Linear Regression      0.242455     0.322419       0.546875
# 1  Random Forest Regressor      0.242455     0.322419       0.546875
#
#    Testing RMSE  Training R2 Score  Testing R2 Score
# 0      0.449503           0.988983          0.984643
# 1      0.449503           0.988983          0.984643

# %% [markdown]
# Plots using seaborm

# %%
sns.histplot(df["Selling_Price"], kde=True)
# Out:
# <Axes: xlabel='Selling_Price', ylabel='Count'>

# %%
sns.boxplot(x="Fuel_Type", y="Selling_Price", data=df)
# Out:
# <Axes: xlabel='Fuel_Type', ylabel='Selling_Price'>

# %%
sns.scatterplot(x="Car_Age", y="Selling_Price", data=df)
# Out:
# <Axes: xlabel='Car_Age', ylabel='Selling_Price'>

# %% [markdown]
# Correlation Heatmap

# %%
plt.figure(figsize=(12,8))
sns.heatmap(df.corr(numeric_only=True), annot=True)
plt.show()
