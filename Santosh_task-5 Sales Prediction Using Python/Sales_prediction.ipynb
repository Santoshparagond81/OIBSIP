# %%
import pandas as pd

# %%
import numpy as np

# %%
import matplotlib.pyplot as plt

# %%
import seaborn as sns

# %%
from sklearn.model_selection import train_test_split

# %%
from sklearn.linear_model import LinearRegression

# %%
df=pd.read_csv("advertising.csv")

# %%
df
# Out:
#      Unnamed: 0  TV Ad Budget ($)  Radio Ad Budget ($)  \
# 0             1             230.1                 37.8
# 1             2              44.5                 39.3
# 2             3              17.2                 45.9
# 3             4             151.5                 41.3
# 4             5             180.8                 10.8
# ..          ...               ...                  ...
# 195         196              38.2                  3.7
# 196         197              94.2                  4.9
# 197         198             177.0                  9.3
# 198         199             283.6                 42.0
# 199         200             232.1                  8.6
#
#      Newspaper Ad Budget ($)  Sales ($)
# 0                       69.2       22.1
# 1                       45.1       10.4
# 2                       69.3        9.3
# 3                       58.5       18.5
# 4                       58.4       12.9
# ..                       ...        ...
# ...

# %%
print("shape of dataset",df.shape)
# Out:
# shape of dataset (200, 5)

# %%
print("check null values",df.isnull().sum())
# Out:
# check null values Unnamed: 0                 0
# TV Ad Budget ($)           0
# Radio Ad Budget ($)        0
# Newspaper Ad Budget ($)    0
# Sales ($)                  0
# dtype: int64

# %%
print((df.isnull().sum() / len(df)) * 100)
# Out:
# Unnamed: 0                 0.0
# TV Ad Budget ($)           0.0
# Radio Ad Budget ($)        0.0
# Newspaper Ad Budget ($)    0.0
# Sales ($)                  0.0
# dtype: float64

# %% [markdown]
# Statistical summary of numerick data

# %%
df.describe()
# Out:
#        Unnamed: 0  TV Ad Budget ($)  Radio Ad Budget ($)  \
# count  200.000000        200.000000           200.000000
# mean   100.500000        147.042500            23.264000
# std     57.879185         85.854236            14.846809
# min      1.000000          0.700000             0.000000
# 25%     50.750000         74.375000             9.975000
# 50%    100.500000        149.750000            22.900000
# 75%    150.250000        218.825000            36.525000
# max    200.000000        296.400000            49.600000
#
#        Newspaper Ad Budget ($)   Sales ($)
# count               200.000000  200.000000
# mean                 30.554000   14.022500
# std                  21.778621    5.217457
# min                   0.300000    1.600000
# 25%                  12.750000   10.375000
# 50%                  25.750000   12.900000
# 75%                  45.100000   17.400000
# max                 114.000000   27.000000

# %%
sns.pairplot(df)

# %%
plt.figure(figsize=(7,5))
sns.scatterplot(y=df["Newspaper Ad Budget ($)"], x=df["Sales ($)"])
plt.xlabel("Newspaper Ad budget")
plt.ylabel("Sales")
plt.title("Sales vs. Newspaper Ad Budget")
# Out:
# Text(0.5, 1.0, 'Sales vs. Newspaper Ad Budget')

# %%
plt.figure(figsize=(7,5))
sns.scatterplot(x=df["Sales ($)"], y=df["Radio Ad Budget ($)"])
plt.ylabel("Radio Advertising Spend")
plt.xlabel("Sales")
plt.title("Sales vs. Radio Advertising Spend")
# Out:
# Text(0.5, 1.0, 'Sales vs. Radio Advertising Spend')

# %%
plt.figure(figsize=(7,5))
sns.scatterplot(x=df["Sales ($)"], y=df["TV Ad Budget ($)"])
plt.xlabel("Newspaper Advertising Spend")
plt.ylabel("Sales")
plt.title("Sales vs. Newspaper Advertising Spend")
plt.show()

# %%
plt.figure(figsize=(8, 6))
correlation = df.corr(numeric_only=True)
sns.heatmap(correlation, annot=True, cmap="coolwarm", fmt=".2f")
plt.title("Correlation Matrix Heatmap")
# Out:
# Text(0.5, 1.0, 'Correlation Matrix Heatmap')

# %% [markdown]
# Training the model

# %%
X_train,X_test,Y_train,Y_test=train_test_split(df,random_state=3,test_size=0.3)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[37], line 1
# ----> 1 X_train,X_test,Y_train,Y_test=train_test_split(df,random_state=3,test_size=0.3)
#
# ValueError: not enough values to unpack (expected 4, got 2)
